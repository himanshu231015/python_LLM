# %% [markdown]
# ### Getting Started With Langchain And OpenAI
# In this quick Start We'll see how to:
#
# * Get Setup With Langchain, LangSmith And Langserve.
# * USe the most basic and common components of langchain: Prompt templetes, modelsand output parsers.
# * Build a Suimple Appplication with Langchain
# * Trace Your QAppplicatiohn weith LangSmith
# * Serve yoyur application with Langserve

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
# LanSmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="True"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# output_version=None profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x0000027BD4C40B50> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000027BD4C40280> root_client=<openai.OpenAI object at 0x0000027BD4C40AF0> root_async_client=<openai.AsyncOpenAI object at 0x0000027BD4C40D00> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('*
# ...

# %%
## Input and get response from llm
result=llm.invoke("What is genrative AI and agents?")

# %%
print(result)
# Out:
# content='Generative AI refers to a class of artificial intelligence systems designed to generate text, images, music, and other forms of content. These systems use machine learning techniques, particularly deep learning, to produce outputs that mimic human creativity and variation. Some of the well-known applications of generative AI include:\n\n1. **Text Generation**: Tools like OpenAI\'s GPT (Generative Pre-trained Transformer) models can produce human-like text based on given prompts, completing sentences, writing essays, or even generating code.\n\n2. **Image Generation**: Models such as DALL-E and Stable Diffusion can create detailed images from textual descriptions, achieving results that often appear artist-created.\n\n3. **Music and Audio**: Systems can compose music or generate realistic-sounding speech, as seen in projects like OpenAI\'s Jukebox.\n\n4. **Game Content**: Procedural content generation uses AI to create levels, maps, or storylines in video games dynamically.\n
# ...

# %%
print(result)
# Out:
# content='Generative AI refers to a class of artificial intelligence systems designed to generate text, images, music, and other forms of content. These systems use machine learning techniques, particularly deep learning, to produce outputs that mimic human creativity and variation. Some of the well-known applications of generative AI include:\n\n1. **Text Generation**: Tools like OpenAI\'s GPT (Generative Pre-trained Transformer) models can produce human-like text based on given prompts, completing sentences, writing essays, or even generating code.\n\n2. **Image Generation**: Models such as DALL-E and Stable Diffusion can create detailed images from textual descriptions, achieving results that often appear artist-created.\n\n3. **Music and Audio**: Systems can compose music or generate realistic-sounding speech, as seen in projects like OpenAI\'s Jukebox.\n\n4. **Game Content**: Procedural content generation uses AI to create levels, maps, or storylines in video games dynamically.\n
# ...

# %%
### Chatprompt Templete
from langchain_core.prompts import ChatPromptTemplate
prompt=ChatPromptTemplate.from_messages(
    [
        ("system","you are an expert Ai Engineer.Provide me answer based on question"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='you are an expert Ai Engineer.Provide me answer based on question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain=prompt|llm
result=chain.invoke({"input":"Can you tell me about langsmith?"})
print(result)
# Out:
# content='LangSmith is a tool developed by LangChain designed to assist in the debugging and evaluation of applications built with language models. It offers a comprehensive suite of features aimed at enhancing the development and deployment of language model-based systems. With LangSmith, developers can:\n\n1. **Track Calls and Evaluate Models**: It allows users to monitor which model calls are being made by their applications, facilitating a better understanding of model performance and operational dynamics.\n\n2. **Debug Applications**: The platform provides tools to identify and troubleshoot issues with language model implementations, streamlining the debugging process.\n\n3. **Improve Model Performance**: By offering insights into model calls and application behavior, developers can optimize the performance and efficiency of their language models.\n\nLangSmith serves as an invaluable resource for developers working with complex language models, enabling them to build more robust,
# ...

# %%
type(result)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## str output parse4r
from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser
response=chain.invoke({"input":"Can you tell me about langsmith?"})
print(response)
# Out:
# Langsmith is not a term or concept that is widely recognized or defined in literature up to October 2023. It's possible that it could be a new term emerging in a specific niche, or it may be a coined term by an individual or a company for a particular concept or product. If you could provide more context or clarification about where you encountered this term or how it's being used, I might be able to offer more relevant insights or help deduce what it could pertain to based on related topics or concepts.
